# %% [markdown]
# # 원, 삼각형, 사각형 구분하기
# - 어려운 테스트 문제를 데이터 부풀리기를 이용한 경우

# %%
import numpy as np 
import tensorflow as tf
seed = 2021
np.random.seed(seed)
tf.random.set_seed(seed)

# %% [markdown]
# ## 데이터셋 생성하기

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
    rescale=1/255.0,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.5,
    zoom_range=[0.8, 2.0],
    horizontal_flip=True,
    vertical_flip=True,
    fill_mode='nearest'
)

# %%
from tensorflow.keras.preprocessing.image import array_to_img, img_to_array, load_img
img = load_img('hard_handwriting_shape/train/triangle/triangle001.png')
x = img_to_array(img)
x = x.reshape((1,) + x.shape)

# %%
i = 0
for batch in train_datagen.flow(x, batch_size=1, save_to_dir='preview',
                        save_prefix='tri', save_format= 'png'):
    i +=1
    if i > 20:
        break

# %%
train_generator = train_datagen.flow_from_directory(
    'hard_handwriting_shape/train',
    target_size=(24,24),
    batch_size=3,
    class_mode='categorical'
)
# Out:
# Found 45 images belonging to 3 classes.

# %%
test_datagen = ImageDataGenerator(rescale=1/255.)
test_generator = test_datagen.flow_from_directory(
    'hard_handwriting_shape/test',
    target_size=(24,24),
    batch_size=3,
    class_mode='categorical'
)
# Out:
# Found 15 images belonging to 3 classes.

# %% [markdown]
# ## 모델 정의/설정

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
model = Sequential([ 
    Conv2D(32, (3,3), input_shape=(24,24,3), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 22, 22, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6400)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               819328
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 387
# =================================================================
# Total params: 839,107
# Trainable params: 839,107
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy']
)

# %% [markdown]
# ## 모델 학습
# - 첫번째 인자 : 훈련데이터셋을 제공할 제네레이터를 지정. 본 예제에서는 앞서 생성한 train_generator으로 지정.
# - steps_per_epoch : 한 epoch에 사용한 스텝 수를 지정. 총 45개의 훈련 샘플이 있고 배치사이즈가 3이므로 15 스텝으로 지정.
# - epochs : 전체 훈련 데이터셋에 대해 학습 반복 횟수를 지정. 50번을 반복적으로 학습.
# - validation_data : 검증데이터셋을 제공할 제네레이터를 지정. 본 예제에서는 앞서 생성한 test_generator으로 지정.
# - validation_steps : 한 epoch 종료 시 마다 검증할 때 사용되는 검증 스텝 수를 지정. 총 15개의 검증 샘플이 있고 배치사이즈가 3이므로 5 스텝으로 지정.

# %%
model.fit(
        train_generator,
        steps_per_epoch=15,
        epochs=200,
        validation_data=test_generator,
        validation_steps=5,
        verbose=2
)
# Out:
# Epoch 1/200
# 15/15 - 0s - loss: 1.5079 - accuracy: 0.4222 - val_loss: 1.0856 - val_accuracy: 0.3333
# Epoch 2/200
# 15/15 - 0s - loss: 1.0792 - accuracy: 0.4222 - val_loss: 1.0436 - val_accuracy: 0.4000
# Epoch 3/200
# 15/15 - 0s - loss: 0.9957 - accuracy: 0.5333 - val_loss: 0.9747 - val_accuracy: 0.5333
# Epoch 4/200
# 15/15 - 0s - loss: 0.8480 - accuracy: 0.5556 - val_loss: 0.9692 - val_accuracy: 0.7333
# Epoch 5/200
# 15/15 - 0s - loss: 0.8355 - accuracy: 0.5778 - val_loss: 1.2724 - val_accuracy: 0.4000
# Epoch 6/200
# 15/15 - 0s - loss: 0.5509 - accuracy: 0.7556 - val_loss: 1.3578 - val_accuracy: 0.6000
# Epoch 7/200
# 15/15 - 0s - loss: 0.5837 - accuracy: 0.8000 - val_loss: 1.5960 - val_accuracy: 0.4000
# Epoch 8/200
# 15/15 - 0s - loss: 0.4711 - accuracy: 0.8000 - val_loss: 0.9677 - val_accuracy: 0.5333
# Epoch 9/200
# 15/15 - 0s - loss: 0.4749 - accuracy: 0.8000 - val_loss: 1.3717 - val_accuracy: 0.5333
# Epoch 10/200
# 15/15 - 0s - loss: 0.2963 - accuracy: 0.9111 - val_loss: 1.2262 - val_accuracy: 0.6667
# Epoch 11/200
# 15/15 - 0s - loss: 0.1949 - accuracy: 0.9778 - val_loss: 1.5824 - val_accuracy: 0.6000
# Epoch 12/200
# 15/15 - 0s - loss: 0.3010 - accuracy: 0.8667 - val_loss: 2.3814 - val_accuracy: 0.4667
# Epoch 13/200
# 15/15 - 0s - loss: 0.4579 - accuracy: 0.8667 - val_loss: 1.0799 - val_accuracy: 0.6667
# Epoch 14/200
# 15/15 - 0s - loss: 0.2745 - accuracy: 0.9111 - val_loss: 1.7249 - val_accuracy: 0.6000
# Epoch 15/200
# 15/15 - 0s - loss: 0.1376 - accuracy: 0.9778 - val_loss: 2.0905 - val_accuracy: 0.6000
# Epoch 16/200
# 15/15 - 0s - loss: 0.0743 - accuracy: 1.0000 - val_loss: 2.3422 - val_accuracy: 0.6667
# Epoch 17/200
# 15/15 - 0s - loss: 0.1316 - accuracy: 0.9556 - val_loss: 1.1127 - val_accuracy: 0.6667
# Epoch 18/200
# 15/15 - 0s - loss: 0.3438 - accuracy: 0.8222 - val_loss: 1.5554 - val_accuracy: 0.6667
# Epoch 19/200
# 15/15 - 0s - loss: 0.1423 - accuracy: 0.9778 - val_loss: 1.5851 - val_accuracy: 0.7333
# Epoch 20/200
# 15/15 - 0s - loss: 0.1317 - accuracy: 0.9111 - val_loss: 1.8601 - val_accuracy: 0.7333
# Epoch 21/200
# 15/15 - 0s - loss: 0.2180 - accuracy: 0.8889 - val_loss: 1.4441 - val_accuracy: 0.7333
# Epoch 22/200
# 15/15 - 0s - loss: 0.1670 - accuracy: 0.9333 - val_loss: 1.6136 - val_accuracy: 0.7333
# Epoch 23/200
# 15/15 - 0s - loss: 0.2894 - accuracy: 0.9333 - val_loss: 2.7362 - val_accuracy: 0.6000
# Epoch 24/200
# 15/15 - 0s - loss: 0.1366 - accuracy: 0.9333 - val_loss: 2.0964 - val_accuracy: 0.6667
# Epoch 25/200
# 15/15 - 0s - loss: 0.2435 - accuracy: 0.9111 - val_loss: 1.7182 - val_accuracy: 0.6667
# Epoch 26/200
# 15/15 - 0s - loss: 0.2353 - accuracy: 0.9556 - val_loss: 1.9955 - val_accuracy: 0.7333
# Epoch 27/200
# 15/15 - 0s - loss: 0.1516 - accuracy: 0.9333 - val_loss: 2.2724 - val_accuracy: 0.6000
# Epoch 28/200
# 15/15 - 0s - loss: 0.0842 - accuracy: 0.9778 - val_loss: 1.7092 - val_accuracy: 0.6667
# Epoch 29/200
# 15/15 - 0s - loss: 0.0550 - accuracy: 0.9778 - val_loss: 1.5530 - val_accuracy: 0.6667
# Epoch 30/200
# 15/15 - 0s - loss: 0.0823 - accuracy: 0.9556 - val_loss: 1.9093 - val_accuracy: 0.6667
# Epoch 31/200
# 15/15 - 0s - loss: 0.0792 - accuracy: 0.9556 - val_loss: 3.1272 - val_accuracy: 0.6000
# Epoch 32/200
# 15/15 - 0s - loss: 0.0253 - accuracy: 1.0000 - val_loss: 2.0799 - val_accuracy: 0.6667
# Epoch 33/200
# 15/15 - 0s - loss: 0.1344 - accuracy: 0.9556 - val_loss: 3.1427 - val_accuracy: 0.6667
# Epoch 34/200
# 15/15 - 0s - loss: 0.0874 - accuracy: 0.9556 - val_loss: 1.9042 - val_accuracy: 0.6667
# Epoch 35/200
# 15/15 - 0s - loss: 0.0226 - accuracy: 1.0000 - val_loss: 1.8943 - val_accuracy: 0.7333
# Epoch 36/200
# 15/15 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 2.3147 - val_accuracy: 0.6667
# Epoch 37/200
# 15/15 - 0s - loss: 0.0183 - accuracy: 1.0000 - val_loss: 2.6003 - val_accuracy: 0.6667
# Epoch 38/200
# 15/15 - 0s - loss: 0.0356 - accuracy: 1.0000 - val_loss: 2.3632 - val_accuracy: 0.7333
# Epoch 39/200
# 15/15 - 0s - loss: 0.0875 - accuracy: 0.9778 - val_loss: 2.7733 - val_accuracy: 0.7333
# Epoch 40/200
# 15/15 - 0s - loss: 0.1114 - accuracy: 0.9778 - val_loss: 2.1753 - val_accuracy: 0.7333
# Epoch 41/200
# 15/15 - 0s - loss: 0.0641 - accuracy: 0.9778 - val_loss: 1.6596 - val_accuracy: 0.7333
# Epoch 42/200
# 15/15 - 0s - loss: 0.0539 - accuracy: 0.9556 - val_loss: 1.5729 - val_accuracy: 0.7333
# Epoch 43/200
# 15/15 - 0s - loss: 0.0286 - accuracy: 1.0000 - val_loss: 1.9045 - val_accuracy: 0.7333
# Epoch 44/200
# 15/15 - 0s - loss: 0.0417 - accuracy: 0.9778 - val_loss: 2.3340 - val_accuracy: 0.7333
# Epoch 45/200
# 15/15 - 0s - loss: 0.0367 - accuracy: 0.9778 - val_loss: 2.1985 - val_accuracy: 0.7333
# Epoch 46/200
# 15/15 - 0s - loss: 0.0534 - accuracy: 0.9778 - val_loss: 1.9735 - val_accuracy: 0.7333
# Epoch 47/200
# 15/15 - 0s - loss: 0.0584 - accuracy: 0.9778 - val_loss: 1.8723 - val_accuracy: 0.7333
# Epoch 48/200
# 15/15 - 0s - loss: 0.0171 - accuracy: 1.0000 - val_loss: 1.7987 - val_accuracy: 0.7333
# Epoch 49/200
# 15/15 - 0s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 1.8239 - val_accuracy: 0.7333
# Epoch 50/200
# 15/15 - 0s - loss: 0.1019 - accuracy: 0.9333 - val_loss: 4.2196 - val_accuracy: 0.6000
# Epoch 51/200
# 15/15 - 0s - loss: 0.0783 - accuracy: 0.9778 - val_loss: 3.0845 - val_accuracy: 0.6667
# Epoch 52/200
# 15/15 - 0s - loss: 0.0970 - accuracy: 0.9778 - val_loss: 4.0902 - val_accuracy: 0.6000
# Epoch 53/200
# 15/15 - 0s - loss: 0.2075 - accuracy: 0.9111 - val_loss: 3.2232 - val_accuracy: 0.6667
# Epoch 54/200
# 15/15 - 0s - loss: 0.1636 - accuracy: 0.9556 - val_loss: 1.7311 - val_accuracy: 0.7333
# Epoch 55/200
# 15/15 - 0s - loss: 0.1923 - accuracy: 0.9111 - val_loss: 2.1827 - val_accuracy: 0.7333
# Epoch 56/200
# 15/15 - 0s - loss: 0.1859 - accuracy: 0.9778 - val_loss: 2.1584 - val_accuracy: 0.7333
# Epoch 57/200
# 15/15 - 0s - loss: 0.0681 - accuracy: 0.9778 - val_loss: 1.8757 - val_accuracy: 0.7333
# Epoch 58/200
# 15/15 - 0s - loss: 0.0810 - accuracy: 1.0000 - val_loss: 2.2678 - val_accuracy: 0.7333
# Epoch 59/200
# 15/15 - 0s - loss: 0.1497 - accuracy: 0.9778 - val_loss: 3.4663 - val_accuracy: 0.6667
# Epoch 60/200
# 15/15 - 0s - loss: 0.1616 - accuracy: 0.9556 - val_loss: 2.6187 - val_accuracy: 0.6667
# Epoch 61/200
# 15/15 - 0s - loss: 0.0851 - accuracy: 0.9556 - val_loss: 2.9862 - val_accuracy: 0.6667
# Epoch 62/200
# 15/15 - 0s - loss: 0.0093 - accuracy: 1.0000 - val_loss: 2.8255 - val_accuracy: 0.6667
# Epoch 63/200
# 15/15 - 0s - loss: 0.0214 - accuracy: 1.0000 - val_loss: 2.5762 - val_accuracy: 0.6667
# Epoch 64/200
# 15/15 - 0s - loss: 0.0285 - accuracy: 1.0000 - val_loss: 2.2990 - val_accuracy: 0.6667
# Epoch 65/200
# 15/15 - 0s - loss: 0.0801 - accuracy: 0.9556 - val_loss: 2.4840 - val_accuracy: 0.7333
# Epoch 66/200
# 15/15 - 0s - loss: 0.0631 - accuracy: 0.9778 - val_loss: 0.9041 - val_accuracy: 0.7333
# Epoch 67/200
# 15/15 - 0s - loss: 0.1409 - accuracy: 0.9556 - val_loss: 2.0749 - val_accuracy: 0.6667
# Epoch 68/200
# 15/15 - 0s - loss: 0.0274 - accuracy: 1.0000 - val_loss: 3.3036 - val_accuracy: 0.6667
# Epoch 69/200
# 15/15 - 0s - loss: 0.0574 - accuracy: 0.9778 - val_loss: 5.2583 - val_accuracy: 0.5333
# Epoch 70/200
# 15/15 - 0s - loss: 0.0441 - accuracy: 0.9778 - val_loss: 2.9687 - val_accuracy: 0.6667
# Epoch 71/200
# 15/15 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 2.0648 - val_accuracy: 0.6667
# Epoch 72/200
# 15/15 - 0s - loss: 0.0078 - accuracy: 1.0000 - val_loss: 2.1082 - val_accuracy: 0.6667
# Epoch 73/200
# 15/15 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 2.2337 - val_accuracy: 0.6667
# Epoch 74/200
# 15/15 - 0s - loss: 0.0111 - accuracy: 1.0000 - val_loss: 2.3666 - val_accuracy: 0.6667
# Epoch 75/200
# 15/15 - 0s - loss: 0.0150 - accuracy: 1.0000 - val_loss: 3.5112 - val_accuracy: 0.6667
# Epoch 76/200
# 15/15 - 0s - loss: 0.1808 - accuracy: 0.9778 - val_loss: 3.1334 - val_accuracy: 0.6667
# Epoch 77/200
# 15/15 - 0s - loss: 0.1045 - accuracy: 0.9778 - val_loss: 1.8380 - val_accuracy: 0.7333
# Epoch 78/200
# 15/15 - 0s - loss: 0.0779 - accuracy: 0.9556 - val_loss: 2.9845 - val_accuracy: 0.7333
# Epoch 79/200
# 15/15 - 0s - loss: 0.1305 - accuracy: 0.9556 - val_loss: 2.2369 - val_accuracy: 0.7333
# Epoch 80/200
# 15/15 - 0s - loss: 0.0178 - accuracy: 1.0000 - val_loss: 2.3450 - val_accuracy: 0.6667
# Epoch 81/200
# 15/15 - 0s - loss: 0.1232 - accuracy: 0.9778 - val_loss: 3.7842 - val_accuracy: 0.6000
# Epoch 82/200
# 15/15 - 0s - loss: 0.0716 - accuracy: 0.9778 - val_loss: 3.0988 - val_accuracy: 0.6667
# Epoch 83/200
# 15/15 - 0s - loss: 0.0502 - accuracy: 0.9778 - val_loss: 2.4981 - val_accuracy: 0.6667
# Epoch 84/200
# 15/15 - 0s - loss: 0.0149 - accuracy: 1.0000 - val_loss: 2.8717 - val_accuracy: 0.6667
# Epoch 85/200
# 15/15 - 0s - loss: 0.0593 - accuracy: 0.9778 - val_loss: 2.9117 - val_accuracy: 0.6667
# Epoch 86/200
# 15/15 - 0s - loss: 0.0487 - accuracy: 0.9778 - val_loss: 2.9900 - val_accuracy: 0.6667
# Epoch 87/200
# 15/15 - 0s - loss: 0.0251 - accuracy: 1.0000 - val_loss: 2.9061 - val_accuracy: 0.6667
# Epoch 88/200
# 15/15 - 0s - loss: 0.1137 - accuracy: 0.9556 - val_loss: 2.3357 - val_accuracy: 0.7333
# Epoch 89/200
# 15/15 - 0s - loss: 0.0602 - accuracy: 0.9778 - val_loss: 2.4930 - val_accuracy: 0.6667
# Epoch 90/200
# 15/15 - 0s - loss: 0.0386 - accuracy: 1.0000 - val_loss: 3.6223 - val_accuracy: 0.6000
# Epoch 91/200
# 15/15 - 0s - loss: 0.0217 - accuracy: 1.0000 - val_loss: 2.7176 - val_accuracy: 0.6667
# Epoch 92/200
# 15/15 - 0s - loss: 0.1529 - accuracy: 0.9778 - val_loss: 4.2908 - val_accuracy: 0.6000
# Epoch 93/200
# 15/15 - 0s - loss: 0.0351 - accuracy: 0.9778 - val_loss: 3.0179 - val_accuracy: 0.6667
# Epoch 94/200
# 15/15 - 0s - loss: 0.0103 - accuracy: 1.0000 - val_loss: 2.9166 - val_accuracy: 0.6667
# Epoch 95/200
# 15/15 - 0s - loss: 0.0563 - accuracy: 0.9778 - val_loss: 2.4414 - val_accuracy: 0.6667
# Epoch 96/200
# 15/15 - 0s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 2.2188 - val_accuracy: 0.7333
# Epoch 97/200
# 15/15 - 0s - loss: 0.0214 - accuracy: 0.9778 - val_loss: 2.6931 - val_accuracy: 0.6667
# Epoch 98/200
# 15/15 - 0s - loss: 0.0681 - accuracy: 0.9556 - val_loss: 3.1769 - val_accuracy: 0.6000
# Epoch 99/200
# 15/15 - 0s - loss: 0.0223 - accuracy: 1.0000 - val_loss: 3.8304 - val_accuracy: 0.6000
# Epoch 100/200
# 15/15 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 3.7295 - val_accuracy: 0.6000
# Epoch 101/200
# 15/15 - 0s - loss: 0.0223 - accuracy: 0.9778 - val_loss: 3.3725 - val_accuracy: 0.6000
# Epoch 102/200
# 15/15 - 0s - loss: 0.0926 - accuracy: 0.9778 - val_loss: 2.6516 - val_accuracy: 0.6667
# Epoch 103/200
# 15/15 - 0s - loss: 0.0056 - accuracy: 1.0000 - val_loss: 2.7476 - val_accuracy: 0.6667
# Epoch 104/200
# 15/15 - 0s - loss: 0.0110 - accuracy: 1.0000 - val_loss: 2.8823 - val_accuracy: 0.6667
# Epoch 105/200
# 15/15 - 0s - loss: 0.0052 - accuracy: 1.0000 - val_loss: 3.3510 - val_accuracy: 0.6000
# Epoch 106/200
# 15/15 - 0s - loss: 6.5230e-04 - accuracy: 1.0000 - val_loss: 3.7128 - val_accuracy: 0.6000
# Epoch 107/200
# 15/15 - 0s - loss: 0.0019 - accuracy: 1.0000 - val_loss: 3.8956 - val_accuracy: 0.6000
# Epoch 108/200
# 15/15 - 0s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 3.4617 - val_accuracy: 0.6000
# Epoch 109/200
# 15/15 - 0s - loss: 0.0087 - accuracy: 1.0000 - val_loss: 4.1325 - val_accuracy: 0.5333
# Epoch 110/200
# 15/15 - 0s - loss: 0.0358 - accuracy: 0.9778 - val_loss: 3.1901 - val_accuracy: 0.6000
# Epoch 111/200
# 15/15 - 0s - loss: 0.0164 - accuracy: 1.0000 - val_loss: 2.1934 - val_accuracy: 0.6667
# Epoch 112/200
# 15/15 - 0s - loss: 0.0038 - accuracy: 1.0000 - val_loss: 2.2648 - val_accuracy: 0.7333
# Epoch 113/200
# 15/15 - 0s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 2.4087 - val_accuracy: 0.7333
# Epoch 114/200
# 15/15 - 0s - loss: 0.0876 - accuracy: 0.9778 - val_loss: 2.5105 - val_accuracy: 0.6667
# Epoch 115/200
# 15/15 - 0s - loss: 0.0441 - accuracy: 0.9778 - val_loss: 2.7695 - val_accuracy: 0.6000
# Epoch 116/200
# 15/15 - 0s - loss: 0.1045 - accuracy: 0.9556 - val_loss: 2.8351 - val_accuracy: 0.7333
# Epoch 117/200
# 15/15 - 0s - loss: 0.0385 - accuracy: 0.9778 - val_loss: 1.2124 - val_accuracy: 0.7333
# Epoch 118/200
# 15/15 - 0s - loss: 0.1533 - accuracy: 0.9556 - val_loss: 1.7366 - val_accuracy: 0.7333
# Epoch 119/200
# 15/15 - 0s - loss: 0.1499 - accuracy: 0.9556 - val_loss: 4.3655 - val_accuracy: 0.6000
# Epoch 120/200
# 15/15 - 0s - loss: 0.0344 - accuracy: 0.9778 - val_loss: 5.1827 - val_accuracy: 0.4667
# Epoch 121/200
# 15/15 - 0s - loss: 0.0402 - accuracy: 0.9778 - val_loss: 3.9398 - val_accuracy: 0.6000
# Epoch 122/200
# 15/15 - 0s - loss: 0.0102 - accuracy: 1.0000 - val_loss: 2.9163 - val_accuracy: 0.6000
# Epoch 123/200
# 15/15 - 0s - loss: 0.0091 - accuracy: 1.0000 - val_loss: 2.9722 - val_accuracy: 0.6000
# Epoch 124/200
# 15/15 - 0s - loss: 0.0144 - accuracy: 1.0000 - val_loss: 2.9067 - val_accuracy: 0.7333
# Epoch 125/200
# 15/15 - 0s - loss: 0.0146 - accuracy: 1.0000 - val_loss: 2.9508 - val_accuracy: 0.7333
# Epoch 126/200
# 15/15 - 0s - loss: 0.0092 - accuracy: 1.0000 - val_loss: 3.9115 - val_accuracy: 0.6000
# Epoch 127/200
# 15/15 - 0s - loss: 0.0023 - accuracy: 1.0000 - val_loss: 4.3436 - val_accuracy: 0.6000
# Epoch 128/200
# 15/15 - 0s - loss: 0.0210 - accuracy: 0.9778 - val_loss: 2.7738 - val_accuracy: 0.6000
# Epoch 129/200
# 15/15 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 2.2049 - val_accuracy: 0.7333
# Epoch 130/200
# 15/15 - 0s - loss: 0.0101 - accuracy: 1.0000 - val_loss: 2.1671 - val_accuracy: 0.7333
# Epoch 131/200
# 15/15 - 0s - loss: 0.0026 - accuracy: 1.0000 - val_loss: 2.2082 - val_accuracy: 0.7333
# Epoch 132/200
# 15/15 - 0s - loss: 0.0021 - accuracy: 1.0000 - val_loss: 2.2441 - val_accuracy: 0.7333
# Epoch 133/200
# 15/15 - 0s - loss: 0.0196 - accuracy: 1.0000 - val_loss: 2.5109 - val_accuracy: 0.6000
# Epoch 134/200
# 15/15 - 0s - loss: 0.0024 - accuracy: 1.0000 - val_loss: 2.4685 - val_accuracy: 0.7333
# Epoch 135/200
# 15/15 - 0s - loss: 0.0426 - accuracy: 0.9778 - val_loss: 3.0493 - val_accuracy: 0.7333
# Epoch 136/200
# 15/15 - 0s - loss: 0.0392 - accuracy: 0.9778 - val_loss: 3.9314 - val_accuracy: 0.6000
# Epoch 137/200
# 15/15 - 0s - loss: 0.0242 - accuracy: 1.0000 - val_loss: 3.7855 - val_accuracy: 0.6000
# Epoch 138/200
# 15/15 - 0s - loss: 0.0147 - accuracy: 1.0000 - val_loss: 2.6724 - val_accuracy: 0.6667
# Epoch 139/200
# 15/15 - 0s - loss: 0.0122 - accuracy: 1.0000 - val_loss: 2.4633 - val_accuracy: 0.7333
# Epoch 140/200
# 15/15 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 2.5825 - val_accuracy: 0.7333
# Epoch 141/200
# 15/15 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 2.6676 - val_accuracy: 0.7333
# Epoch 142/200
# 15/15 - 0s - loss: 0.0046 - accuracy: 1.0000 - val_loss: 3.1119 - val_accuracy: 0.6667
# Epoch 143/200
# 15/15 - 0s - loss: 0.0025 - accuracy: 1.0000 - val_loss: 3.2904 - val_accuracy: 0.6667
# Epoch 144/200
# 15/15 - 0s - loss: 2.4712e-04 - accuracy: 1.0000 - val_loss: 3.3581 - val_accuracy: 0.6667
# Epoch 145/200
# 15/15 - 0s - loss: 0.0013 - accuracy: 1.0000 - val_loss: 3.3941 - val_accuracy: 0.6000
# Epoch 146/200
# 15/15 - 0s - loss: 5.6286e-04 - accuracy: 1.0000 - val_loss: 3.3902 - val_accuracy: 0.6000
# Epoch 147/200
# 15/15 - 0s - loss: 0.0634 - accuracy: 0.9778 - val_loss: 4.6062 - val_accuracy: 0.6000
# Epoch 148/200
# 15/15 - 0s - loss: 0.2052 - accuracy: 0.9556 - val_loss: 3.9292 - val_accuracy: 0.5333
# Epoch 149/200
# 15/15 - 0s - loss: 0.2136 - accuracy: 0.9333 - val_loss: 2.5575 - val_accuracy: 0.5333
# Epoch 150/200
# 15/15 - 0s - loss: 0.1336 - accuracy: 0.9111 - val_loss: 1.3959 - val_accuracy: 0.6667
# Epoch 151/200
# 15/15 - 0s - loss: 0.0300 - accuracy: 1.0000 - val_loss: 1.6030 - val_accuracy: 0.7333
# Epoch 152/200
# 15/15 - 0s - loss: 0.2642 - accuracy: 0.8889 - val_loss: 2.4917 - val_accuracy: 0.5333
# Epoch 153/200
# 15/15 - 0s - loss: 0.0476 - accuracy: 0.9556 - val_loss: 2.6498 - val_accuracy: 0.5333
# Epoch 154/200
# 15/15 - 0s - loss: 0.0879 - accuracy: 0.9333 - val_loss: 2.8276 - val_accuracy: 0.5333
# Epoch 155/200
# 15/15 - 0s - loss: 0.0404 - accuracy: 0.9778 - val_loss: 2.4416 - val_accuracy: 0.6667
# Epoch 156/200
# 15/15 - 0s - loss: 0.0097 - accuracy: 1.0000 - val_loss: 2.9481 - val_accuracy: 0.5333
# Epoch 157/200
# 15/15 - 0s - loss: 0.0141 - accuracy: 1.0000 - val_loss: 2.4223 - val_accuracy: 0.6667
# Epoch 158/200
# 15/15 - 0s - loss: 0.0115 - accuracy: 1.0000 - val_loss: 2.0465 - val_accuracy: 0.6667
# Epoch 159/200
# 15/15 - 0s - loss: 0.0528 - accuracy: 0.9778 - val_loss: 4.4584 - val_accuracy: 0.4667
# Epoch 160/200
# 15/15 - 0s - loss: 0.0223 - accuracy: 0.9778 - val_loss: 4.8962 - val_accuracy: 0.4667
# Epoch 161/200
# 15/15 - 0s - loss: 0.1893 - accuracy: 0.9556 - val_loss: 1.4987 - val_accuracy: 0.7333
# Epoch 162/200
# 15/15 - 0s - loss: 0.0636 - accuracy: 0.9778 - val_loss: 1.4061 - val_accuracy: 0.7333
# Epoch 163/200
# 15/15 - 0s - loss: 0.0368 - accuracy: 0.9778 - val_loss: 1.3846 - val_accuracy: 0.7333
# Epoch 164/200
# 15/15 - 0s - loss: 0.0157 - accuracy: 1.0000 - val_loss: 1.5408 - val_accuracy: 0.7333
# Epoch 165/200
# 15/15 - 0s - loss: 0.0293 - accuracy: 0.9778 - val_loss: 1.5184 - val_accuracy: 0.7333
# Epoch 166/200
# 15/15 - 0s - loss: 0.0339 - accuracy: 0.9778 - val_loss: 1.5247 - val_accuracy: 0.7333
# Epoch 167/200
# 15/15 - 0s - loss: 0.0135 - accuracy: 1.0000 - val_loss: 1.6274 - val_accuracy: 0.7333
# Epoch 168/200
# 15/15 - 0s - loss: 0.0035 - accuracy: 1.0000 - val_loss: 1.6589 - val_accuracy: 0.7333
# Epoch 169/200
# 15/15 - 0s - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.7672 - val_accuracy: 0.7333
# Epoch 170/200
# 15/15 - 0s - loss: 0.0517 - accuracy: 0.9778 - val_loss: 3.9156 - val_accuracy: 0.5333
# Epoch 171/200
# 15/15 - 0s - loss: 0.0500 - accuracy: 0.9778 - val_loss: 6.8131 - val_accuracy: 0.4000
# Epoch 172/200
# 15/15 - 0s - loss: 0.1005 - accuracy: 0.9556 - val_loss: 3.7210 - val_accuracy: 0.6000
# Epoch 173/200
# 15/15 - 0s - loss: 0.0463 - accuracy: 0.9778 - val_loss: 2.5852 - val_accuracy: 0.6000
# Epoch 174/200
# 15/15 - 0s - loss: 0.0278 - accuracy: 0.9778 - val_loss: 2.6608 - val_accuracy: 0.6667
# Epoch 175/200
# 15/15 - 0s - loss: 0.0129 - accuracy: 1.0000 - val_loss: 2.6631 - val_accuracy: 0.6667
# Epoch 176/200
# 15/15 - 0s - loss: 0.0112 - accuracy: 1.0000 - val_loss: 2.4969 - val_accuracy: 0.6667
# Epoch 177/200
# 15/15 - 0s - loss: 0.0236 - accuracy: 0.9778 - val_loss: 2.4769 - val_accuracy: 0.6667
# Epoch 178/200
# 15/15 - 0s - loss: 0.0030 - accuracy: 1.0000 - val_loss: 2.6402 - val_accuracy: 0.6667
# Epoch 179/200
# 15/15 - 0s - loss: 0.0442 - accuracy: 0.9778 - val_loss: 1.9620 - val_accuracy: 0.7333
# Epoch 180/200
# 15/15 - 0s - loss: 0.0973 - accuracy: 0.9556 - val_loss: 2.0166 - val_accuracy: 0.7333
# Epoch 181/200
# 15/15 - 0s - loss: 0.0755 - accuracy: 0.9778 - val_loss: 2.8206 - val_accuracy: 0.7333
# Epoch 182/200
# 15/15 - 0s - loss: 0.0051 - accuracy: 1.0000 - val_loss: 4.5060 - val_accuracy: 0.5333
# Epoch 183/200
# 15/15 - 0s - loss: 0.0113 - accuracy: 1.0000 - val_loss: 4.2926 - val_accuracy: 0.5333
# Epoch 184/200
# 15/15 - 0s - loss: 0.0014 - accuracy: 1.0000 - val_loss: 3.9528 - val_accuracy: 0.5333
# Epoch 185/200
# 15/15 - 0s - loss: 0.0187 - accuracy: 1.0000 - val_loss: 3.8589 - val_accuracy: 0.5333
# Epoch 186/200
# 15/15 - 0s - loss: 0.0875 - accuracy: 0.9556 - val_loss: 4.1115 - val_accuracy: 0.5333
# Epoch 187/200
# 15/15 - 0s - loss: 0.0061 - accuracy: 1.0000 - val_loss: 3.2714 - val_accuracy: 0.6000
# Epoch 188/200
# 15/15 - 0s - loss: 0.0540 - accuracy: 0.9778 - val_loss: 3.8245 - val_accuracy: 0.5333
# Epoch 189/200
# 15/15 - 0s - loss: 0.0099 - accuracy: 1.0000 - val_loss: 4.1001 - val_accuracy: 0.5333
# Epoch 190/200
# 15/15 - 0s - loss: 0.0015 - accuracy: 1.0000 - val_loss: 4.1175 - val_accuracy: 0.5333
# Epoch 191/200
# 15/15 - 0s - loss: 0.0022 - accuracy: 1.0000 - val_loss: 4.0802 - val_accuracy: 0.5333
# Epoch 192/200
# 15/15 - 0s - loss: 0.0926 - accuracy: 0.9778 - val_loss: 2.8100 - val_accuracy: 0.6000
# Epoch 193/200
# 15/15 - 0s - loss: 0.0041 - accuracy: 1.0000 - val_loss: 2.1321 - val_accuracy: 0.6667
# Epoch 194/200
# 15/15 - 0s - loss: 0.0042 - accuracy: 1.0000 - val_loss: 2.0240 - val_accuracy: 0.7333
# Epoch 195/200
# 15/15 - 0s - loss: 0.0356 - accuracy: 0.9778 - val_loss: 2.0077 - val_accuracy: 0.8000
# Epoch 196/200
# 15/15 - 0s - loss: 0.0342 - accuracy: 0.9778 - val_loss: 2.4849 - val_accuracy: 0.7333
# Epoch 197/200
# 15/15 - 0s - loss: 0.0037 - accuracy: 1.0000 - val_loss: 2.7060 - val_accuracy: 0.7333
# Epoch 198/200
# 15/15 - 0s - loss: 0.0318 - accuracy: 0.9778 - val_loss: 3.4822 - val_accuracy: 0.6000
# Epoch 199/200
# 15/15 - 0s - loss: 0.0016 - accuracy: 1.0000 - val_loss: 3.6979 - val_accuracy: 0.6000
# Epoch 200/200
# 15/15 - 0s - loss: 0.0498 - accuracy: 0.9778 - val_loss: 2.8543 - val_accuracy: 0.6667

# %% [markdown]
# ## 모델 평가

# %%
model.evaluate(test_generator, steps=5)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 2.8543 - accuracy: 0.6667
# [2.8542988300323486, 0.6666666865348816]
