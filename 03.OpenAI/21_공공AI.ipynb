# %% [markdown]
# ## 공공 인공지능 Open API 활용

# %%
with open('etriaikey.txt') as kfile:
    etri_key = kfile.read()

# %%
import urllib3
import json
import base64
openApiURL = "http://aiopen.etri.re.kr:8000/ObjectDetect"

# %%
import os
img_file = '../02.CNN/Animals/eagle.jpg'
_, image_type = os.path.splitext(img_file)
image_type
# Out:
# '.jpg'

# %%
image_type = 'jpg' if image_type == '.jfif' else image_type[1:]
image_type
# Out:
# 'jpg'

# %%
with open(img_file, 'rb') as file:
    image_contents = base64.b64encode(file.read()).decode("utf8")

# %%
request_json = {
    "access_key": etri_key,
    "argument": {
        "type": image_type,
        "file": image_contents
    }
}

# %%
http = urllib3.PoolManager()
response = http.request(
    "POST",
    openApiURL,
    headers={"Content-Type": "application/json; charset=UTF-8"},
    body=json.dumps(request_json)
)

# %%
print("[responseCode] " + str(response.status))
# Out:
# [responseCode] 200

# %%
print(response.data)
# Out:
# b'{"result":0,"return_object":{"data":[{"class":"bird","confidence":"0.996838","x":"161","y":"96","width":"1533","height":"1229"}]}}'

# %%
result = json.loads(response.data)
result
# Out:
# {'result': 0,
#  'return_object': {'data': [{'class': 'bird',
#     'confidence': '0.996838',
#     'x': '161',
#     'y': '96',
#     'width': '1533',
#     'height': '1229'}]}}

# %%
obj_list = result['return_object']['data']
obj_list[0]
# Out:
# {'class': 'bird',
#  'confidence': '0.996838',
#  'x': '161',
#  'y': '96',
#  'width': '1533',
#  'height': '1229'}

# %% [markdown]
# ## 시각화

# %%
from PIL import Image, ImageDraw, ImageFont
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = Image.open(img_file)
plt.imshow(image)
plt.show()

# %%
draw = ImageDraw.Draw(image)
obj = obj_list[0]
name = obj['class']
x = int(obj['x'])
y = int(obj['y'])
w = int(obj['width'])
h = int(obj['height'])
draw.text((x+10,y+10), name, font=ImageFont.truetype('malgun.ttf', 100), fill=(255,0,0))
draw.rectangle(((x,y), (x+w, y+h)), outline=(255,0,0), width=2)

# %%
plt.imshow(image)
plt.show()
